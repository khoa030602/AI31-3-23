# %% [markdown]
# <a href="https://colab.research.google.com/github/khoa030602/AI31-3-23/blob/main/AI_31_3_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist
(train_images,train_labels),(test_images,test_labels)= mnist.load_data()
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
train_labels.shape
# Out:
# (60000,)

# %%
test_labels.shape
# Out:
# (10000,)

# %%
digit=train_images[60]
import matplotlib.pyplot as plt
plt.imshow(digit)
plt.show
print('so nay la:',train_labels[60])
# Out:
# so nay la: 4

# %%
for i in range(10):
  plt.subplot(3,5,i+1)
  plt.tight_layout
  plt.imshow(train_images[i],cmap='gray',interpolation='None')
  plt.title('so nay la:{}'.format(train_labels[i]))
  plt.xticks
  plt.yticks

# %%
from keras.models import Sequential #mang ANN
from keras.layers import Dense #ket noi
model=Sequential()
model.add(Dense(512,activation='relu',input_shape=(28*28,)))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 512)               401920
#
#  dense_10 (Dense)            (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images=train_images.reshape((60000,28*28))
train_images=train_images.astype('float32')/255

train_images.shape
# Out:
# (60000, 784)

# %%
test_images=test_images.reshape((10000,28*28))
test_images=test_images.astype('float32')/255
test_images.shape
# Out:
# (10000, 784)

# %%
from keras.utils import to_categorical
train_labels=to_categorical(train_labels,10)
test_labels=to_categorical(test_labels,10)

# %%
train_labels.shape
# Out:
# (60000, 10)

# %%
test_labels.shape
# Out:
# (10000, 10)

# %%
model.compile(optimizer='rmsprop', loss= 'categorical_crossentropy', metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=20, batch_size=128)
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('do chinh xac:', test_loss)
print('do chinh xac:', test_acc)
# Out:
# Epoch 1/20
# 469/469 [==============================] - 5s 9ms/step - loss: 0.2634 - accuracy: 0.9241
# Epoch 2/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1068 - accuracy: 0.9689
# Epoch 3/20
# 469/469 [==============================] - 6s 14ms/step - loss: 0.0710 - accuracy: 0.9785
# Epoch 4/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0510 - accuracy: 0.9850
# Epoch 5/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0384 - accuracy: 0.9886
# Epoch 6/20
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0292 - accuracy: 0.9913
# Epoch 7/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0224 - accuracy: 0.9934
# Epoch 8/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0168 - accuracy: 0.9951
# Epoch 9/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0126 - accuracy: 0.9967
# Epoch 10/20
# ...

# %%
from keras.datasets import cifar10
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_test.shape
# Out:
# (10000, 1)

# %%
for i in range(10):
  plt.subplot(3,5,i+1)
  plt.tight_layout
  plt.imshow(x_train[i],cmap='gray',interpolation='None')
  plt.title('nay la:{}'.format(y_test[i]))
  plt.xticks
  plt.yticks

# %%
from keras.models import Sequential #mang ANN
from keras.layers import Dense #ket noi
model=Sequential()
model.add(Dense(512,activation='relu',input_shape=(32*32*3,)))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_11 (Dense)            (None, 512)               1573376
#
#  dense_12 (Dense)            (None, 10)                5130
#
# ...
# Total params: 1,578,506
# Trainable params: 1,578,506
# Non-trainable params: 0
# _________________________________________________________________
